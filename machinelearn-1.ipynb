# %%
import pandas as pd
import seaborn as sns
# %matplotlib inline

import matplotlib.pyplot as plt

# %%
# Define example plot
x = [1,6,10]
y = [5,13,27]

# Create line plot of x and y
plt.plot(x, y)
